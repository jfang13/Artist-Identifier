# %% [markdown]
# # Identify the Artist

# %%
from pathlib import Path, PurePath

home_dir = Path.home()
main_dir = home_dir / "OneDrive - BOOZ ALLEN HAMILTON"/"Documents" / "GitHub" / "bah-advanced" / "Capstone"
data_dir = main_dir / "archive" 
image_dir = data_dir / "images" /"images"
resized_dir = data_dir / "resized" / "resized"

# %%
# Import libraries
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from textwrap import wrap
from datetime import datetime
import random
import seaborn as sns
from sklearn.metrics import *


import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras import Sequential, Input, Model
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.layers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import *

tf.random.set_seed(1)

# %%
# Load data
artists = pd.read_csv(data_dir / 'artists.csv')
artists.shape
# Out:
# (50, 8)

# %%
artists.head()
# Out:
#    id                name        years                         genre  \
# 0   0   Amedeo Modigliani  1884 - 1920                 Expressionism
# 1   1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism
# 2   2        Diego Rivera  1886 - 1957       Social Realism,Muralism
# 3   3        Claude Monet  1840 - 1926                 Impressionism
# 4   4       Rene Magritte  1898 - 1967      Surrealism,Impressionism
#
#   nationality                                                bio  \
# 0     Italian  Amedeo Clemente Modigliani (Italian pronunciat...
# 1     Russian  Wassily Wassilyevich Kandinsky (Russian: Васи́...
# 2     Mexican  Diego María de la Concepción Juan Nepomuceno E...
# 3      French  Oscar-Claude Monet (; French: [klod mɔnɛ]; 14 ...
# 4     Belgian  René François Ghislain Magritte (French: [ʁəne...
#
#                                         wikipedia  paintings
# 0  http://en.wikipedia.org/wiki/Amedeo_Modigliani        193
# 1  http://en.wikipedia.org/wiki/Wassily_Kandinsky         88
# 2       http://en.wikipedia.org/wiki/Diego_Rivera         70
# 3       http://en.wikipedia.org/wiki/Claude_Monet         73
# 4      http://en.wikipedia.org/wiki/René_Magritte        194

# %%
# sort artists by number of paintings
artists = artists.sort_values(by=['paintings'], ascending=False)

# Create a dataframe with artists having more than 100 paintings
artists_top = artists[artists['paintings'] >= 100].reset_index()
artists_top = artists_top[['name', 'paintings']]

#artists_top['class_weight'] = max(artists_top.paintings)/artists_top.paintings
artists_top['class_weight'] = artists_top.paintings.sum() / (artists_top.shape[0] * artists_top.paintings)
artists_top
# Out:
#                      name  paintings  class_weight
# 0        Vincent van Gogh        877      0.269517
# 1             Edgar Degas        702      0.336705
# 2           Pablo Picasso        439      0.538421
# 3   Pierre-Auguste Renoir        336      0.703472
# 4          Albrecht Dürer        328      0.720630
# 5            Paul Gauguin        311      0.760021
# 6          Francisco Goya        291      0.812257
# 7               Rembrandt        262      0.902163
# 8           Alfred Sisley        259      0.912613
# 9                  Titian        255      0.926928
# 10           Marc Chagall        239      0.988982
# 11          Rene Magritte        194      1.218385
# 12      Amedeo Modigliani        193      1.224698
# 13              Paul Klee        188      1.257270
# 14          Henri Matisse        186      1.270789
# 15            Andy Warhol        181      1.305893
# 16         Mikhail Vrubel        171      1.382261
# 17      Sandro Botticelli        164      1.441260
# 18      Leonardo da Vinci        143      1.652914
# 19      Peter Paul Rubens        141      1.676359
# 20          Salvador Dali        139      1.700480
# 21       Hieronymus Bosch        137      1.725304
# 22         Pieter Bruegel        134      1.763930
# 23        Diego Velazquez        128      1.846615
# 24       Kazimir Malevich        126      1.875926
# 25            Frida Kahlo        120      1.969722
# 26      Giotto di Bondone        119      1.986275
# 27           Gustav Klimt        117      2.020228
# 28                Raphael        109      2.168502
# 29              Joan Miro        102      2.317320

# %%
# Set class weights - assign higher weights to underrepresented classes
class_weights = artists_top['class_weight'].to_dict()
class_weights
# Out:
# {0: 0.269517293804637,
#  1: 0.33670465337132005,
#  2: 0.5384206529992407,
#  3: 0.7034722222222223,
#  4: 0.720630081300813,
#  5: 0.760021436227224,
#  6: 0.8122565864833906,
#  7: 0.9021628498727735,
#  8: 0.9126126126126126,
#  9: 0.9269281045751634,
#  10: 0.9889818688981868,
#  11: 1.2183848797250858,
#  12: 1.2246977547495683,
#  13: 1.2572695035460992,
#  14: 1.2707885304659499,
#  15: 1.3058931860036833,
#  16: 1.382261208576998,
#  17: 1.441260162601626,
#  18: 1.652913752913753,
#  19: 1.6763593380614656,
#  20: 1.7004796163069544,
#  21: 1.7253041362530415,
#  22: 1.7639303482587065,
#  23: 1.8466145833333334,
#  24: 1.875925925925926,
#  25: 1.9697222222222222,
#  26: 1.9862745098039216,
#  27: 2.0202279202279203,
#  28: 2.1685015290519876,
#  29: 2.3173202614379087}

# %% [markdown]
# ## Data Processing

# %%
# Print few random paintings

n = 5
fig, axes = plt.subplots(1, n, figsize=(20,10))

for i in range(n):
       
    random_image = random.choice(os.listdir(resized_dir))
    random_image_file = os.path.join(resized_dir, random_image)
    
    image = plt.imread(random_image_file)
    
    axes[i].imshow(image)
    axes[i].set_title("Artist: " + random_image.rsplit('_', 1)[0].replace('_',' '))
    axes[i].axis('off')

plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
artists_top.shape[0]
# Out:
# 30

# %%
batch_size = 16
train_input_shape = (224, 224, 3)
n_classes = artists_top.shape[0]

artists_top_name = artists_top['name'].str.replace(' ', '_').values

train_datagen = ImageDataGenerator(validation_split=0.2,
                                    rescale=1./255,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    vertical_flip=True)

#test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(directory=image_dir,
                                                    target_size= train_input_shape[0:2],
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    subset="training",
                                                    class_mode='categorical',
                                                    classes=artists_top_name.tolist())

validation_generator = train_datagen.flow_from_directory(directory=image_dir,
                                                        target_size=train_input_shape[0:2],
                                                        batch_size=batch_size,
                                                        subset="validation",
                                                        class_mode='categorical',
                                                        shuffle=True,
                                                        classes=artists_top_name.tolist())

STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = validation_generator.n//validation_generator.batch_size
print("Total number of batches =", STEP_SIZE_TRAIN, "and", STEP_SIZE_VALID)
# Out:
# Found 5687 images belonging to 30 classes.
# Found 1404 images belonging to 30 classes.
# Total number of batches = 355 and 87

# %%
# print a random augmented version of a painting

fig, axes = plt.subplots(1, 2, figsize=(20,10))

random_artist = random.choice(artists_top_name)
random_image = random.choice(os.listdir(os.path.join(image_dir, random_artist)))
random_image_file = os.path.join(image_dir, random_artist, random_image)

# Original image
image = plt.imread(random_image_file)
axes[0].imshow(image)
axes[0].set_title("Original: " + random_artist.replace('_', ' '))
axes[0].axis('off')

# Transformed image
aug_image = train_datagen.random_transform(image)
axes[1].imshow(aug_image)
axes[1].set_title("Transformed: " + random_artist.replace('_', ' '))
axes[1].axis('off')

plt.show()

# %% [markdown]
# ## Model Building

# %%
# Load pre-trained model

base_model = VGG16(weights='imagenet', 
                      include_top=False, 
                      input_shape=train_input_shape)

for layer in base_model.layers:
    layer.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 12s 0us/step

# %%
# Add additional layers

X = base_model.output
X = Flatten()(X)

X = Dense(512, kernel_initializer='he_uniform')(X)
X = Dropout(0.5)(X)
X = BatchNormalization()(X)
X = Activation('relu')(X)

X = Dense(16, kernel_initializer='he_uniform')(X)
#X = Dropout(0.5)(X)
X = BatchNormalization()(X)
X = Activation('relu')(X)

output = Dense(n_classes, activation='softmax')(X)

model = Model(inputs=base_model.input, outputs=output)

# %%
# compile model

optimizer = Adam(lr=0.0001)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1, 
                           mode='auto', restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, 
                              verbose=1, mode='auto')

# %%
#Train model

n_epoch = 50
history1 = model.fit_generator(generator=train_generator, 
                               steps_per_epoch=STEP_SIZE_TRAIN,
                               validation_data=validation_generator, 
                               validation_steps=STEP_SIZE_VALID,
                               epochs=n_epoch,
                               shuffle=True,
                               verbose=1,
                               callbacks=[reduce_lr],
                               #use_multiprocessing=True,
                               workers=16,
                               class_weight=class_weights
                              )
# Out:
# C:\Users\597154\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 355/355 [==============================] - 2025s 6s/step - loss: 3.4549 - accuracy: 0.0496 - val_loss: 3.3287 - val_accuracy: 0.0539
# Epoch 2/50
# 355/355 [==============================] - 1962s 6s/step - loss: 3.2000 - accuracy: 0.0993 - val_loss: 3.1308 - val_accuracy: 0.1480
# Epoch 3/50
# 355/355 [==============================] - 1967s 6s/step - loss: 3.0751 - accuracy: 0.1523 - val_loss: 3.0818 - val_accuracy: 0.1818
# Epoch 4/50
# 355/355 [==============================] - 2021s 6s/step - loss: 3.0067 - accuracy: 0.1817 - val_loss: 3.0067 - val_accuracy: 0.1976
# Epoch 5/50
# 355/355 [==============================] - 2007s 6s/step - loss: 2.8974 - accuracy: 0.1919 - val_loss: 2.9109 - val_accuracy: 0.2249
# Epoch 6/50
# 355/355 [==============================] - 1989s 6s/step - loss: 2.8144 - accuracy: 0.2275 - val_loss: 2.8706 - val_accuracy: 0.2184
# Epoch 7/50
# 355/355 [==============================] - 2101s 6s/step - loss: 2.6410 - accuracy: 0.2461 - val_loss: 2.7610 - val_accuracy: 0.2500
# Epoch 8/50
# 355/355 [==============================] - 2106s 6s/step - loss: 2.6403 - accuracy: 0.2768 - val_loss: 2.8136 - val_accuracy: 0.2414
# Epoch 9/50
# 355/355 [==============================] - 2090s 6s/step - loss: 2.5341 - accuracy: 0.2944 - val_loss: 2.7270 - val_accuracy: 0.2601
# Epoch 10/50
# 355/355 [==============================] - 2117s 6s/step - loss: 2.4200 - accuracy: 0.3387 - val_loss: 2.7829 - val_accuracy: 0.2543
# Epoch 11/50
# 355/355 [==============================] - 2092s 6s/step - loss: 2.3447 - accuracy: 0.3398 - val_loss: 2.4571 - val_accuracy: 0.3499
# Epoch 12/50
# 355/355 [==============================] - 2030s 6s/step - loss: 2.2862 - accuracy: 0.3730 - val_loss: 2.6176 - val_accuracy: 0.2874
# Epoch 13/50
# 355/355 [==============================] - 1995s 6s/step - loss: 2.2022 - accuracy: 0.3925 - val_loss: 2.3855 - val_accuracy: 0.3455
# Epoch 14/50
# 355/355 [==============================] - 1993s 6s/step - loss: 2.0940 - accuracy: 0.4091 - val_loss: 2.4976 - val_accuracy: 0.3455
# Epoch 15/50
# 355/355 [==============================] - 2018s 6s/step - loss: 2.0315 - accuracy: 0.4420 - val_loss: 2.3062 - val_accuracy: 0.3786
# Epoch 16/50
# 355/355 [==============================] - 2000s 6s/step - loss: 1.9324 - accuracy: 0.4602 - val_loss: 2.2588 - val_accuracy: 0.3894
# Epoch 17/50
# 355/355 [==============================] - 1991s 6s/step - loss: 1.8608 - accuracy: 0.4886 - val_loss: 2.2776 - val_accuracy: 0.4131
# Epoch 18/50
# 355/355 [==============================] - 2004s 6s/step - loss: 1.8390 - accuracy: 0.4818 - val_loss: 2.2630 - val_accuracy: 0.4131
# Epoch 19/50
# 355/355 [==============================] - 2010s 6s/step - loss: 1.6999 - accuracy: 0.5016 - val_loss: 2.0386 - val_accuracy: 0.4418
# Epoch 20/50
# 355/355 [==============================] - 2005s 6s/step - loss: 1.6165 - accuracy: 0.5395 - val_loss: 2.0545 - val_accuracy: 0.4497
# Epoch 21/50
# 355/355 [==============================] - 2036s 6s/step - loss: 1.5576 - accuracy: 0.5502 - val_loss: 2.0210 - val_accuracy: 0.4713
# Epoch 22/50
# 355/355 [==============================] - 2080s 6s/step - loss: 1.4684 - accuracy: 0.5748 - val_loss: 1.8994 - val_accuracy: 0.5000
# Epoch 23/50
# 355/355 [==============================] - 2091s 6s/step - loss: 1.3902 - accuracy: 0.5968 - val_loss: 1.8797 - val_accuracy: 0.5101
# Epoch 24/50
# 355/355 [==============================] - 2118s 6s/step - loss: 1.2846 - accuracy: 0.6331 - val_loss: 1.8401 - val_accuracy: 0.5000
# Epoch 25/50
# 355/355 [==============================] - 2147s 6s/step - loss: 1.1914 - accuracy: 0.6342 - val_loss: 1.8081 - val_accuracy: 0.4907
# Epoch 26/50
# 355/355 [==============================] - 2002s 6s/step - loss: 1.1296 - accuracy: 0.6572 - val_loss: 1.9519 - val_accuracy: 0.4921
# Epoch 27/50
# 355/355 [==============================] - 1949s 5s/step - loss: 1.0999 - accuracy: 0.6637 - val_loss: 1.7512 - val_accuracy: 0.5316
# Epoch 28/50
# 355/355 [==============================] - 1952s 5s/step - loss: 1.0227 - accuracy: 0.6878 - val_loss: 1.6969 - val_accuracy: 0.5489
# Epoch 29/50
# 355/355 [==============================] - 1932s 5s/step - loss: 0.9275 - accuracy: 0.7214 - val_loss: 1.7334 - val_accuracy: 0.5374
# Epoch 30/50
# 355/355 [==============================] - 1926s 5s/step - loss: 0.9334 - accuracy: 0.7149 - val_loss: 1.7826 - val_accuracy: 0.5022
# Epoch 31/50
# 355/355 [==============================] - 2019s 6s/step - loss: 0.8579 - accuracy: 0.7121 - val_loss: 1.9353 - val_accuracy: 0.4935
# Epoch 32/50
# 355/355 [==============================] - 2007s 6s/step - loss: 0.8342 - accuracy: 0.7349 - val_loss: 1.7698 - val_accuracy: 0.5424
# Epoch 33/50
# 355/355 [==============================] - 2045s 6s/step - loss: 0.7603 - accuracy: 0.7522 - val_loss: 1.5696 - val_accuracy: 0.5855
# Epoch 34/50
# 355/355 [==============================] - 2104s 6s/step - loss: 0.6961 - accuracy: 0.7800 - val_loss: 1.6084 - val_accuracy: 0.5596
# Epoch 35/50
# 355/355 [==============================] - 2040s 6s/step - loss: 0.6829 - accuracy: 0.7888 - val_loss: 1.6651 - val_accuracy: 0.5503
# Epoch 36/50
# 355/355 [==============================] - 2035s 6s/step - loss: 0.6216 - accuracy: 0.8058 - val_loss: 1.7256 - val_accuracy: 0.5553
# Epoch 37/50
# 355/355 [==============================] - 2036s 6s/step - loss: 0.5993 - accuracy: 0.8132 - val_loss: 1.6554 - val_accuracy: 0.5582
# Epoch 38/50
# 355/355 [==============================] - 2171s 6s/step - loss: 0.5150 - accuracy: 0.8329 - val_loss: 1.7082 - val_accuracy: 0.5582
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 39/50
# 355/355 [==============================] - 2256s 6s/step - loss: 0.4145 - accuracy: 0.8645 - val_loss: 1.3283 - val_accuracy: 0.6494
# Epoch 40/50
# 355/355 [==============================] - 2210s 6s/step - loss: 0.3484 - accuracy: 0.8974 - val_loss: 1.3359 - val_accuracy: 0.6494
# Epoch 41/50
# 355/355 [==============================] - 2230s 6s/step - loss: 0.3398 - accuracy: 0.9160 - val_loss: 1.3200 - val_accuracy: 0.6566
# Epoch 42/50
# 355/355 [==============================] - 2245s 6s/step - loss: 0.3177 - accuracy: 0.9210 - val_loss: 1.3245 - val_accuracy: 0.6473
# Epoch 43/50
# 355/355 [==============================] - 2265s 6s/step - loss: 0.3102 - accuracy: 0.9165 - val_loss: 1.3311 - val_accuracy: 0.6602
# Epoch 44/50
# 355/355 [==============================] - 2053s 6s/step - loss: 0.3065 - accuracy: 0.9260 - val_loss: 1.3053 - val_accuracy: 0.6473
# Epoch 45/50
# 355/355 [==============================] - 2027s 6s/step - loss: 0.2973 - accuracy: 0.9306 - val_loss: 1.3432 - val_accuracy: 0.6422
# Epoch 46/50
# 355/355 [==============================] - 2011s 6s/step - loss: 0.2791 - accuracy: 0.9374 - val_loss: 1.3028 - val_accuracy: 0.6559
# Epoch 47/50
# 355/355 [==============================] - 2000s 6s/step - loss: 0.2787 - accuracy: 0.9270 - val_loss: 1.3251 - val_accuracy: 0.6444
# Epoch 48/50
# 355/355 [==============================] - 2024s 6s/step - loss: 0.2637 - accuracy: 0.9445 - val_loss: 1.2915 - val_accuracy: 0.6552
# Epoch 49/50
# 355/355 [==============================] - 2021s 6s/step - loss: 0.2400 - accuracy: 0.9475 - val_loss: 1.3355 - val_accuracy: 0.6573
# Epoch 50/50
# 355/355 [==============================] - 2001s 6s/step - loss: 0.2477 - accuracy: 0.9454 - val_loss: 1.2849 - val_accuracy: 0.6638

# %% [markdown]
# ## Graphs

# %%
history = {}
history['loss'] = history1.history['loss'] #+ history2.history['loss']
history['accuracy'] = history1.history['accuracy'] #+ history2.history['acc']
history['val_loss'] = history1.history['val_loss'] #+ history2.history['val_loss']
history['val_accuracy'] = history1.history['val_accuracy'] #+ history2.history['val_acc']
history['lr'] = history1.history['lr'] #+ history2.history['lr']

# %%
def plot_training(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    epochs = range(len(acc))

    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    
    axes[0].plot(epochs, acc, 'r-', label='Training Accuracy')
    axes[0].plot(epochs, val_acc, 'b--', label='Validation Accuracy')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].legend(loc='best')

    axes[1].plot(epochs, loss, 'r-', label='Training Loss')
    axes[1].plot(epochs, val_loss, 'b--', label='Validation Loss')
    axes[1].set_title('Training and Validation Loss')
    axes[1].legend(loc='best')
    
    plt.savefig("trial8_50epoch_nootherchanges.png")
    plt.show()
    
plot_training(history)

# %% [markdown]
# ## Evaluation

# %%
# Prediction accuracy on train data
score = model.evaluate_generator(train_generator, verbose=1)
print("Prediction accuracy on train data =", score[1])
# Out:
# C:\Users\597154\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 356/356 [==============================] - 526s 1s/step - loss: 0.1803 - accuracy: 0.9698
# Prediction accuracy on train data = 0.9697555899620056

# %%
# Prediction accuracy on CV data
score = model.evaluate_generator(validation_generator, verbose=1)
print("Prediction accuracy on CV data =", score[1])
# Out:
# 88/88 [==============================] - 128s 1s/step - loss: 1.2957 - accuracy: 0.6546
# Prediction accuracy on CV data = 0.6545584201812744

# %%
# Classification Report and confusion matrix

tick_labels = artists_top_name.tolist()

def showClassficationReport_Generator(model, validation_generator, STEP_SIZE_VALID):
    # Loop on each generator batch and predict
    y_pred, y_true = [], []
    for i in range(STEP_SIZE_VALID):
        (X,y) = next(validation_generator)
        y_pred.append(model.predict(X))
        y_true.append(y)
    
    # Create a flat list for y_true and y_pred
    y_pred = [subresult for result in y_pred for subresult in result]
    y_true = [subresult for result in y_true for subresult in result]
    
    # Update Truth vector based on argmax
    y_true = np.argmax(y_true, axis=1)
    y_true = np.asarray(y_true).ravel()
    
    # Update Prediction vector based on argmax
    y_pred = np.argmax(y_pred, axis=1)
    y_pred = np.asarray(y_pred).ravel()
    
    # Confusion Matrix
    fig, ax = plt.subplots(figsize=(20,20))
    conf_matrix = confusion_matrix(y_true, y_pred, labels=np.arange(n_classes))
    conf_matrix = conf_matrix/np.sum(conf_matrix, axis=1)
    sns.heatmap(conf_matrix, annot=True, fmt=".2f", square=True, cbar=False, 
                cmap='PRGn', xticklabels=tick_labels, yticklabels=tick_labels,
                ax=ax)
    ax.set_ylabel('Actual')
    ax.set_xlabel('Predicted')
    ax.set_title('Confusion Matrix')
    plt.show()
    
    print('Classification Report:')
    print(classification_report(y_true, y_pred, labels=np.arange(n_classes), target_names=artists_top_name.tolist()))

showClassficationReport_Generator(model, validation_generator, STEP_SIZE_VALID)
# Out:
# Classification Report:
#                        precision    recall  f1-score   support
#
#      Vincent_van_Gogh       0.70      0.67      0.69       174
#           Edgar_Degas       0.68      0.71      0.70       139
#         Pablo_Picasso       0.36      0.57      0.44        87
# Pierre-Auguste_Renoir       0.71      0.79      0.75        67
#        Albrecht_Dürer       0.88      0.89      0.89        65
#          Paul_Gauguin       0.87      0.63      0.73        62
#        Francisco_Goya       0.66      0.65      0.65        57
#             Rembrandt       0.66      0.63      0.65        52
#         Alfred_Sisley       0.74      0.86      0.79        49
#                Titian       0.52      0.56      0.54        50
#          Marc_Chagall       0.80      0.68      0.74        47
#         Rene_Magritte       0.82      0.47      0.60        38
#     Amedeo_Modigliani       0.94      0.82      0.87        38
#             Paul_Klee       0.62      0.50      0.55        36
#         Henri_Matisse       0.62      0.56      0.59        36
#           Andy_Warhol       0.71      0.69      0.70        36
#        Mikhail_Vrubel       0.47      0.55      0.51        33
#     Sandro_Botticelli       0.46      0.75      0.57        32
#     Leonardo_da_Vinci       0.49      0.61      0.54        28
#     Peter_Paul_Rubens       0.59      0.61      0.60        28
#         Salvador_Dali       0.58      0.67      0.62        27
#      Hieronymus_Bosch       0.90      0.67      0.77        27
#        Pieter_Bruegel       0.75      0.69      0.72        26
#       Diego_Velazquez       0.50      0.36      0.42        25
#      Kazimir_Malevich       0.74      0.56      0.64        25
#           Frida_Kahlo       0.93      0.58      0.72        24
#     Giotto_di_Bondone       0.87      0.57      0.68        23
#          Gustav_Klimt       0.50      0.50      0.50        22
#               Raphael       0.53      0.40      0.46        20
#             Joan_Miro       0.43      0.32      0.36        19
#
#              accuracy                           0.65      1392
#             macro avg       0.67      0.62      0.63      1392
#          weighted avg       0.67      0.65      0.65      1392

# %%
# Prediction


n = 5
fig, axes = plt.subplots(1, n, figsize=(25,10))

for i in range(n):
    random_artist = random.choice(artists_top_name)
    random_image = random.choice(os.listdir(os.path.join(image_dir, random_artist)))
    random_image_file = os.path.join(image_dir, random_artist, random_image)

    # Original image
    test_image = image.load_img(random_image_file, target_size=(train_input_shape[0:2]))

    # Predict artist
    test_image = image.img_to_array(test_image)
    test_image /= 255.
    test_image = np.expand_dims(test_image, axis=0)

    prediction = model.predict(test_image)
    prediction_probability = np.amax(prediction)
    prediction_idx = np.argmax(prediction)

    labels = train_generator.class_indices
    labels = dict((v,k) for k,v in labels.items())

    title = "Actual artist = {}\nPredicted artist = {}\nPrediction probability = {:.2f} %" \
                .format(random_artist.replace('_', ' '), labels[prediction_idx].replace('_', ' '),
                        prediction_probability*100)

    # Print image
    axes[i].imshow(plt.imread(random_image_file))
    axes[i].set_title(title)
    axes[i].axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-7de09042e081> in <module>
#      11
#      12     # Original image
# ---> 13     test_image = image.load_img(random_image_file, target_size=(train_input_shape[0:2]))
#      14
#      15     # Predict artist
#
# AttributeError: 'numpy.ndarray' object has no attribute 'load_img'
